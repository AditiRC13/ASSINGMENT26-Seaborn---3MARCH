# %% [markdown]
# Que 1: Name any five plots that we can plot using the Seaborn library. Also, state the uses of each plot.

# %%
import seaborn as sns 
df=sns.load_dataset('iris')
sns.load_dataset('iris')
# Out:
#      sepal_length  sepal_width  petal_length  petal_width    species
# 0             5.1          3.5           1.4          0.2     setosa
# 1             4.9          3.0           1.4          0.2     setosa
# 2             4.7          3.2           1.3          0.2     setosa
# 3             4.6          3.1           1.5          0.2     setosa
# 4             5.0          3.6           1.4          0.2     setosa
# ..            ...          ...           ...          ...        ...
# 145           6.7          3.0           5.2          2.3  virginica
# 146           6.3          2.5           5.0          1.9  virginica
# 147           6.5          3.0           5.2          2.0  virginica
# 148           6.2          3.4           5.4          2.3  virginica
# 149           5.9          3.0           5.1          1.8  virginica
#
# [150 rows x 5 columns]

# %% [markdown]
# #plot 1
# a. Distplot

# %% [markdown]
# (1)  Dist plot gives us the histogram of the selected continuous variable.

# %% [markdown]
# (2)  It is an example of a univariate analysis,
#      We can change the number of bins i.e. number of vertical bars in a histogram

# %%
sns.displot(df['sepal_length'])
sns.set(rc={'figure.figsize':(2,8)})

# %% [markdown]
# #plot2  b.Joint Plot

# %% [markdown]
# It is the combination of the distplot of two variables.

# %% [markdown]
# It is an example of bivariate analysis.We additionally obtain a scatter plot between the variable to reflecting their linear relationship. We can customize the scatter plot into a hexagonal plot, where, more the color intensity, the more will be the number of observations.

# %%
import seaborn as sns

# For Plot 1
sns.jointplot(x = df['sepal_length'], y = df['petal_length'], kind = 'scatter',height=3,ratio=5,space=0.2)

# For Plot 2
sns.jointplot(x = df['sepal_length'], y = df['petal_length'],kind = 'hex',height=3,ratio=5,space=0.2)

# %% [markdown]
# #plot 3 c.Bar Plot

# %%
import seaborn as sns
import matplotlib.pyplot as plt
sns.barplot(x = df['species'], y = df['petal_width'])
plt.rcParams['figure.figsize']=5,5

# %% [markdown]
# #plot 4 d.Strip Plot

# %% [markdown]
# It’s a plot between a continuous variable and a categorical variable.
# It plots as a scatter plot but supplementarily uses categorical encodings of the categorical variable.

# %%
import seaborn as sns
sns.stripplot(y = df['sepal_length'], x = df['species'],size=5,edgecolor='maroon')
# Out:
# <AxesSubplot: xlabel='species', ylabel='sepal_length'>

# %% [markdown]
# #plot 5 e. Heat Map

# %% [markdown]
# In the given raw dataset ‘df’, we have seven numeric variables. So, let us generate a correlation matrix between these seven variables.

# %%
df.corr()
sns.heatmap(df.corr(), annot = True, cmap = 'viridis')
# Out:
# /tmp/ipykernel_77/1688052567.py:1: FutureWarning: The default value of numeric_only in DataFrame.corr is deprecated. In a future version, it will default to False. Select only valid columns or specify the value of numeric_only to silence this warning.
#   df.corr()
# /tmp/ipykernel_77/1688052567.py:2: FutureWarning: The default value of numeric_only in DataFrame.corr is deprecated. In a future version, it will default to False. Select only valid columns or specify the value of numeric_only to silence this warning.
#   sns.heatmap(df.corr(), annot = True, cmap = 'viridis')
# <AxesSubplot: >

# %% [markdown]
# Que 2: Load the "fmri" dataset using the load_dataset function of seaborn. Plot a line plot using x =
# "timepoint" and y = "signal" for different events and regions.

# %%
sns.load_dataset('fmri')
# Out:
#      subject  timepoint event    region    signal
# 0        s13         18  stim  parietal -0.017552
# 1         s5         14  stim  parietal -0.080883
# 2        s12         18  stim  parietal -0.081033
# 3        s11         18  stim  parietal -0.046134
# 4        s10         18  stim  parietal -0.037970
# ...      ...        ...   ...       ...       ...
# 1059      s0          8   cue   frontal  0.018165
# 1060     s13          7   cue   frontal -0.029130
# 1061     s12          7   cue   frontal -0.004939
# 1062     s11          7   cue   frontal -0.025367
# 1063      s0          0   cue  parietal -0.006899
#
# [1064 rows x 5 columns]

# %%
import numpy as np
import seaborn as sns; sns.set()
import matplotlib.pyplot as plt
fmri = sns.load_dataset("fmri")
fmri.sort_values('timepoint',inplace=True)
ax = sns.lineplot(x="timepoint", y="signal", data=fmri)
arr = np.ones(len(fmri))
arr[:300] = 0
arr[600:] = 2
fmri['background'] = arr
ax1 = sns.lineplot(x="timepoint", y="signal", hue="event", data=fmri)
ax2 = sns.lineplot(x="timepoint", y="signal", hue="region", data=fmri,color='maroon')

# %% [markdown]
# Que 3: Load the "titanic" dataset using the load_dataset function of seaborn. Plot two box plots using x =
# 'pclass', y = 'age' and y = 'fare'.

# %%
df1=sns.load_dataset('titanic')
sns.load_dataset('titanic')
# Out:
#      survived  pclass     sex   age  sibsp  parch     fare embarked   class  \
# 0           0       3    male  22.0      1      0   7.2500        S   Third
# 1           1       1  female  38.0      1      0  71.2833        C   First
# 2           1       3  female  26.0      0      0   7.9250        S   Third
# 3           1       1  female  35.0      1      0  53.1000        S   First
# 4           0       3    male  35.0      0      0   8.0500        S   Third
# ..        ...     ...     ...   ...    ...    ...      ...      ...     ...
# 886         0       2    male  27.0      0      0  13.0000        S  Second
# 887         1       1  female  19.0      0      0  30.0000        S   First
# 888         0       3  female   NaN      1      2  23.4500        S   Third
# 889         1       1    male  26.0      0      0  30.0000        C   First
# 890         0       3    male  32.0      0      0   7.7500        Q   Third
#
#        who  adult_male deck  embark_town alive  alone
# ...

# %%
sns.boxplot(data=df1, x ='pclass', y = 'age')
# Out:
# <AxesSubplot: xlabel='pclass', ylabel='age'>

# %%
sns.boxplot(data=df1, x ='pclass', y = 'fare')
# Out:
# <AxesSubplot: xlabel='pclass', ylabel='fare'>

# %% [markdown]
# Que 4: Use the "diamonds" dataset from seaborn to plot a histogram for the 'price' column. Use the hue
# parameter for the 'cut' column of the diamonds dataset.

# %%
df2=sns.load_dataset('diamonds')
sns.load_dataset('diamonds')
# Out:
#        carat        cut color clarity  depth  table  price     x     y     z
# 0       0.23      Ideal     E     SI2   61.5   55.0    326  3.95  3.98  2.43
# 1       0.21    Premium     E     SI1   59.8   61.0    326  3.89  3.84  2.31
# 2       0.23       Good     E     VS1   56.9   65.0    327  4.05  4.07  2.31
# 3       0.29    Premium     I     VS2   62.4   58.0    334  4.20  4.23  2.63
# 4       0.31       Good     J     SI2   63.3   58.0    335  4.34  4.35  2.75
# ...      ...        ...   ...     ...    ...    ...    ...   ...   ...   ...
# 53935   0.72      Ideal     D     SI1   60.8   57.0   2757  5.75  5.76  3.50
# 53936   0.72       Good     D     SI1   63.1   55.0   2757  5.69  5.75  3.61
# 53937   0.70  Very Good     D     SI1   62.8   60.0   2757  5.66  5.68  3.56
# 53938   0.86    Premium     H     SI2   61.0   58.0   2757  6.15  6.12  3.74
# 53939   0.75      Ideal     D     SI2   62.2   55.0   2757  5.83  5.87  3.64
#
# [53940 rows x 10 columns]

# %%
sns.histplot(data=df2, x="price",hue='cut')
# Out:
# <AxesSubplot: xlabel='price', ylabel='Count'>

# %% [markdown]
# Que 5: Use the "iris" dataset from seaborn to plot a pair plot. Use the hue parameter for the "species" columnof the iris dataset.

# %%
df3=sns.load_dataset('iris')
sns.load_dataset('iris')
# Out:
#      sepal_length  sepal_width  petal_length  petal_width    species
# 0             5.1          3.5           1.4          0.2     setosa
# 1             4.9          3.0           1.4          0.2     setosa
# 2             4.7          3.2           1.3          0.2     setosa
# 3             4.6          3.1           1.5          0.2     setosa
# 4             5.0          3.6           1.4          0.2     setosa
# ..            ...          ...           ...          ...        ...
# 145           6.7          3.0           5.2          2.3  virginica
# 146           6.3          2.5           5.0          1.9  virginica
# 147           6.5          3.0           5.2          2.0  virginica
# 148           6.2          3.4           5.4          2.3  virginica
# 149           5.9          3.0           5.1          1.8  virginica
#
# [150 rows x 5 columns]

# %%
sns.pairplot(df3,hue='species')

# %% [markdown]
# Que 6: Use the "flights" dataset from seaborn to plot a heatmap.

# %%
df4=sns.load_dataset('flights')
sns.load_dataset('flights')
# Out:
#      year month  passengers
# 0    1949   Jan         112
# 1    1949   Feb         118
# 2    1949   Mar         132
# 3    1949   Apr         129
# 4    1949   May         121
# ..    ...   ...         ...
# 139  1960   Aug         606
# 140  1960   Sep         508
# 141  1960   Oct         461
# 142  1960   Nov         390
# 143  1960   Dec         432
#
# [144 rows x 3 columns]

# %%
sns.heatmap(df4.corr(), cmap = 'tab20')
# Out:
# /tmp/ipykernel_77/3381414155.py:1: FutureWarning: The default value of numeric_only in DataFrame.corr is deprecated. In a future version, it will default to False. Select only valid columns or specify the value of numeric_only to silence this warning.
#   sns.heatmap(df4.corr(), cmap = 'tab20')
# <AxesSubplot: >
